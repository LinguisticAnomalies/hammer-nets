# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

def make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers):
    plt.rcParams["figure.figsize"] = (20,5)
    plt.plot(layers, train_con_auc, label="control train")
    plt.plot(layers, test_con_auc, label="control test")
    plt.plot(layers, train_diff_auc, label="c-d train")
    plt.plot(layers, test_diff_auc, label="c-d test")
    plt.plot(layers, train_ratio_auc, label="c/d train")
    plt.plot(layers, test_ratio_auc, label="c/d test")
    if max(layers) == 11:
        plt.xlabel("n-th layers")
        plt.ylabel("AUC")
        plt.title("AUC on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(0, 12, 1.0))
    else:
        plt.xlabel("first n layers")
        plt.ylabel("AUC")
        plt.title("AUC on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(1, 13, 1.0))
    for x, y in zip(layers, train_diff_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_diff_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, train_ratio_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_ratio_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    plt.show()
    print("c-d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_diff_auc, test_diff_auc)[0], 3),
                                                                    round(pearsonr(train_diff_auc, test_diff_auc)[1], 3)))
    print("c/d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_ratio_auc, test_ratio_auc)[0], 3),
                                                                    round(pearsonr(train_ratio_auc, test_ratio_auc)[1], 3)))


    
def make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers):
    plt.rcParams["figure.figsize"] = (20,5)
    plt.plot(layers, train_con_accu, label="control train")
    plt.plot(layers, test_con_accu, label="control test")
    plt.plot(layers, train_diff_accu, label="c-d train")
    plt.plot(layers, test_diff_accu, label="c-d test")
    plt.plot(layers, train_ratio_accu, label="c/d train")
    plt.plot(layers, test_ratio_accu, label="c/d test")
    if max(layers) == 12:
        plt.xlabel("n-th layers")
        plt.ylabel("Accuracy")
        plt.title("Accuracy on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(0, 12, 1.0))
    else:
        plt.xlabel("first n layers")
        plt.ylabel("Accuracy")
        plt.title("Accuracy on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(1, 13, 1.0))
    for x, y in zip(layers, train_diff_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_diff_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, train_ratio_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_ratio_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    plt.show()
    print("c-d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_diff_accu, test_diff_accu)[0], 3),
                                                                    round(pearsonr(train_diff_accu, test_diff_accu)[1], 3)))
    print("c/d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_ratio_accu, test_ratio_accu)[0], 3),
                                                                    round(pearsonr(train_ratio_accu, test_ratio_accu)[1], 3)))

# %% [markdown]
# ## Onetime Layer-wise with 25% Attention Heads Zeroed

# %%
layers = list(range(0, 12))
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.497, 0.513, 0.376, 0.417, 0.333, 0.553, 0.618, 0.414, 0.483, 0.689, 0.579, 0.458]
train_diff_accu = [0.523, 0.446, 0.446, 0.431, 0.431, 0.477, 0.523, 0.477, 0.538, 0.723, 0.508, 0.538]
test_diff_auc = [0.725, 0.379, 0.492, 0.562, 0.592, 0.658, 0.588, 0.271, 0.488, 0.55, 0.425, 0.363]
test_diff_accu = [0.794, 0.294, 0.559, 0.588, 0.559, 0.588, 0.5, 0.294, 0.5, 0.412, 0.382, 0.412]
train_ratio_auc = [0.524, 0.487, 0.358, 0.426, 0.341, 0.519, 0.618, 0.414, 0.531, 0.7, 0.557, 0.47]
train_ratio_accu = [0.508, 0.4, 0.4, 0.462, 0.431, 0.462, 0.631, 0.431, 0.523, 0.6, 0.523, 0.415]
test_ratio_auc = [0.792, 0.446, 0.529, 0.579, 0.612, 0.679, 0.588, 0.35, 0.583, 0.717, 0.429, 0.462]
test_ratio_accu = [0.794, 0.471, 0.559, 0.529, 0.588, 0.588, 0.471, 0.382, 0.588, 0.706, 0.471, 0.471]
train_log_auc = [0.524, 0.487, 0.358, 0.426, 0.341, 0.519, 0.618, 0.414, 0.531, 0.7, 0.557, 0.47]
train_log_accu = [0.508, 0.4, 0.4, 0.462, 0.431, 0.462, 0.631, 0.431, 0.523, 0.6, 0.523, 0.415]
test_log_auc = [0.792, 0.446, 0.529, 0.579, 0.612, 0.679, 0.588, 0.35, 0.583, 0.717, 0.429, 0.462]
test_log_accu = [0.794, 0.471, 0.559, 0.529, 0.588, 0.588, 0.471, 0.382, 0.588, 0.706, 0.471, 0.471]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.179
# p-value: 0.578
# c/d model:
# Pearson correction coeffificent: 0.363
# p-value: 0.246
# c-d model:
# Pearson correction coeffificent: -0.129
# p-value: 0.69
# c/d model:
# Pearson correction coeffificent: 0.3
# p-value: 0.343

# %% [markdown]
# ## Onetime Layer-wise with 50% Attention Heads Zeroed

# %%
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.546, 0.365, 0.36, 0.384, 0.349, 0.594, 0.631, 0.453, 0.544, 0.55, 0.475, 0.395]
train_diff_accu = [0.508, 0.385, 0.323, 0.446, 0.431, 0.492, 0.477, 0.585, 0.523, 0.585, 0.462, 0.446]
test_diff_auc = [0.725, 0.429, 0.583, 0.529, 0.45, 0.517, 0.546, 0.442, 0.392, 0.283, 0.333, 0.467]
test_diff_accu = [0.618, 0.676, 0.5, 0.471, 0.471, 0.471, 0.441, 0.412, 0.382, 0.382, 0.294, 0.676]
train_ratio_auc = [0.481, 0.341, 0.346, 0.387, 0.347, 0.608, 0.648, 0.454, 0.588, 0.574, 0.459, 0.398]
train_ratio_accu = [0.385, 0.338, 0.415, 0.415, 0.354, 0.585, 0.569, 0.492, 0.569, 0.569, 0.4, 0.4]
test_ratio_auc = [0.842, 0.454, 0.596, 0.55, 0.404, 0.625, 0.538, 0.575, 0.475, 0.4, 0.45, 0.538]
test_ratio_accu = [0.853, 0.647, 0.529, 0.559, 0.382, 0.559, 0.5, 0.618, 0.294, 0.441, 0.412, 0.324]
train_log_auc = [0.481, 0.341, 0.346, 0.387, 0.347, 0.608, 0.648, 0.454, 0.588, 0.574, 0.459, 0.398]
train_log_accu = [0.385, 0.338, 0.415, 0.415, 0.354, 0.585, 0.569, 0.492, 0.569, 0.569, 0.4, 0.4]
test_log_auc = [0.842, 0.454, 0.596, 0.55, 0.404, 0.625, 0.538, 0.575, 0.475, 0.4, 0.45, 0.538]
test_log_accu = [0.853, 0.647, 0.529, 0.559, 0.382, 0.559, 0.5, 0.618, 0.294, 0.441, 0.412, 0.324]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.046
# p-value: 0.888
# c/d model:
# Pearson correction coeffificent: 0.089
# p-value: 0.784
# c-d model:
# Pearson correction coeffificent: -0.422
# p-value: 0.172
# c/d model:
# Pearson correction coeffificent: -0.236
# p-value: 0.461

# %% [markdown]
# ## Onetime Layer-wise with 75% Attention Heads Zeroed

# %%
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.5, 0.431, 0.462, 0.445, 0.502, 0.56, 0.478, 0.44, 0.476, 0.45, 0.494, 0.369]
train_diff_accu = [0.4, 0.492, 0.569, 0.492, 0.538, 0.569, 0.523, 0.492, 0.492, 0.431, 0.462, 0.446]
test_diff_auc = [0.688, 0.521, 0.546, 0.504, 0.633, 0.458, 0.579, 0.521, 0.342, 0.292, 0.346, 0.404]
test_diff_accu = [0.706, 0.412, 0.471, 0.529, 0.588, 0.529, 0.588, 0.412, 0.382, 0.265, 0.441, 0.412]
train_ratio_auc = [0.495, 0.407, 0.426, 0.42, 0.514, 0.566, 0.505, 0.486, 0.462, 0.39, 0.447, 0.327]
train_ratio_accu = [0.431, 0.508, 0.446, 0.446, 0.538, 0.523, 0.477, 0.446, 0.477, 0.431, 0.492, 0.431]
test_ratio_auc = [0.796, 0.496, 0.575, 0.562, 0.642, 0.65, 0.617, 0.625, 0.496, 0.392, 0.475, 0.512]
test_ratio_accu = [0.824, 0.559, 0.471, 0.471, 0.529, 0.618, 0.529, 0.471, 0.441, 0.441, 0.412, 0.382]
train_log_auc = [0.495, 0.407, 0.426, 0.42, 0.514, 0.566, 0.505, 0.486, 0.462, 0.39, 0.447, 0.327]
train_log_accu = [0.431, 0.508, 0.446, 0.446, 0.538, 0.523, 0.477, 0.446, 0.477, 0.431, 0.492, 0.431]
test_log_auc = [0.796, 0.496, 0.575, 0.562, 0.642, 0.65, 0.617, 0.625, 0.496, 0.392, 0.475, 0.512]
test_log_accu = [0.824, 0.559, 0.471, 0.471, 0.529, 0.618, 0.529, 0.471, 0.441, 0.441, 0.412, 0.382]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.216
# p-value: 0.5
# c/d model:
# Pearson correction coeffificent: 0.654
# p-value: 0.021
# c-d model:
# Pearson correction coeffificent: 0.119
# p-value: 0.712
# c/d model:
# Pearson correction coeffificent: 0.094
# p-value: 0.772

# %% [markdown]
# ## Onetime Layer-wise with 100% Attention Heads Zeroed

# %%
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.524, 0.407, 0.423, 0.48, 0.407, 0.583, 0.602, 0.437, 0.5, 0.502, 0.472, 0.354]
train_diff_accu = [0.523, 0.385, 0.492, 0.523, 0.354, 0.554, 0.6, 0.385, 0.508, 0.523, 0.523, 0.462]
test_diff_auc = [0.588, 0.321, 0.438, 0.579, 0.596, 0.35, 0.533, 0.546, 0.35, 0.296, 0.296, 0.379]
test_diff_accu = [0.559, 0.206, 0.471, 0.588, 0.441, 0.412, 0.471, 0.588, 0.353, 0.382, 0.353, 0.471]
train_ratio_auc = [0.487, 0.376, 0.41, 0.448, 0.426, 0.579, 0.657, 0.461, 0.494, 0.495, 0.41, 0.299]
train_ratio_accu = [0.431, 0.446, 0.508, 0.523, 0.4, 0.569, 0.492, 0.462, 0.538, 0.508, 0.385, 0.323]
test_ratio_auc = [0.65, 0.35, 0.517, 0.621, 0.612, 0.542, 0.608, 0.671, 0.55, 0.454, 0.392, 0.588]
test_ratio_accu = [0.559, 0.294, 0.471, 0.588, 0.5, 0.5, 0.412, 0.676, 0.618, 0.382, 0.441, 0.647]
train_log_auc = [0.487, 0.376, 0.41, 0.448, 0.426, 0.579, 0.657, 0.461, 0.494, 0.495, 0.41, 0.299]
train_log_accu = [0.431, 0.446, 0.508, 0.523, 0.4, 0.569, 0.492, 0.462, 0.538, 0.508, 0.385, 0.323]
test_log_auc = [0.65, 0.35, 0.517, 0.621, 0.612, 0.542, 0.608, 0.671, 0.55, 0.454, 0.392, 0.588]
test_log_accu = [0.559, 0.294, 0.471, 0.588, 0.5, 0.5, 0.412, 0.676, 0.618, 0.382, 0.441, 0.647]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.054
# p-value: 0.868
# c/d model:
# Pearson correction coeffificent: 0.262
# p-value: 0.41
# c-d model:
# Pearson correction coeffificent: 0.134
# p-value: 0.679
# c/d model:
# Pearson correction coeffificent: -0.108
# p-value: 0.738

# %% [markdown]
# ## Accumulated Layers with 25% Attention Heads Zeroed

# %%
layers = list(range(1, 13))
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.497, 0.508, 0.544, 0.579, 0.585, 0.546, 0.544, 0.571, 0.566, 0.566, 0.552, 0.549]
train_diff_accu = [0.523, 0.646, 0.4, 0.462, 0.523, 0.615, 0.569, 0.662, 0.662, 0.538, 0.646, 0.615]
test_diff_auc = [0.725, 0.629, 0.708, 0.771, 0.763, 0.658, 0.729, 0.733, 0.721, 0.675, 0.662, 0.633]
test_diff_accu = [0.794, 0.588, 0.618, 0.647, 0.676, 0.529, 0.853, 0.882, 0.794, 0.618, 0.559, 0.588]
train_ratio_auc = [0.524, 0.509, 0.563, 0.568, 0.563, 0.513, 0.511, 0.536, 0.55, 0.561, 0.555, 0.553]
train_ratio_accu = [0.508, 0.523, 0.477, 0.492, 0.477, 0.477, 0.538, 0.508, 0.508, 0.523, 0.492, 0.508]
test_ratio_auc = [0.792, 0.763, 0.833, 0.858, 0.858, 0.8, 0.846, 0.825, 0.825, 0.812, 0.796, 0.771]
test_ratio_accu = [0.794, 0.676, 0.735, 0.735, 0.706, 0.559, 0.735, 0.647, 0.618, 0.618, 0.647, 0.853]
train_log_auc = [0.524, 0.509, 0.563, 0.568, 0.563, 0.513, 0.511, 0.536, 0.55, 0.561, 0.555, 0.553]
train_log_accu = [0.508, 0.523, 0.477, 0.492, 0.477, 0.477, 0.538, 0.508, 0.508, 0.523, 0.492, 0.508]
test_log_auc = [0.792, 0.763, 0.833, 0.858, 0.858, 0.8, 0.846, 0.825, 0.825, 0.812, 0.796, 0.771]
test_log_accu = [0.794, 0.676, 0.735, 0.735, 0.706, 0.559, 0.735, 0.647, 0.618, 0.618, 0.647, 0.853]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.464
# p-value: 0.129
# c/d model:
# Pearson correction coeffificent: 0.416
# p-value: 0.179
# c-d model:
# Pearson correction coeffificent: 0.114
# p-value: 0.725
# c/d model:
# Pearson correction coeffificent: 0.134
# p-value: 0.678

# %% [markdown]
# ## Accumulated Layers with 50% Attention Heads Zeroed

# %%
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.546, 0.596, 0.586, 0.61, 0.619, 0.638, 0.649, 0.66, 0.648, 0.635, 0.624, 0.601]
train_diff_accu = [0.508, 0.554, 0.585, 0.585, 0.631, 0.677, 0.662, 0.692, 0.615, 0.585, 0.585, 0.523]
test_diff_auc = [0.725, 0.712, 0.7, 0.721, 0.733, 0.767, 0.779, 0.733, 0.712, 0.7, 0.679, 0.663]
test_diff_accu = [0.618, 0.735, 0.706, 0.618, 0.618, 0.706, 0.735, 0.706, 0.529, 0.529, 0.471, 0.5]
train_ratio_auc = [0.481, 0.564, 0.555, 0.56, 0.569, 0.577, 0.588, 0.591, 0.59, 0.596, 0.597, 0.607]
train_ratio_accu = [0.385, 0.462, 0.492, 0.585, 0.615, 0.585, 0.554, 0.646, 0.646, 0.554, 0.569, 0.6]
test_ratio_auc = [0.842, 0.854, 0.838, 0.871, 0.888, 0.896, 0.9, 0.879, 0.888, 0.871, 0.862, 0.854]
test_ratio_accu = [0.853, 0.794, 0.735, 0.735, 0.676, 0.735, 0.676, 0.647, 0.824, 0.794, 0.794, 0.735]
train_log_auc = [0.481, 0.564, 0.555, 0.56, 0.569, 0.577, 0.588, 0.591, 0.59, 0.596, 0.597, 0.607]
train_log_accu = [0.385, 0.462, 0.492, 0.585, 0.615, 0.585, 0.554, 0.646, 0.646, 0.554, 0.569, 0.6]
test_log_auc = [0.842, 0.854, 0.838, 0.871, 0.888, 0.896, 0.9, 0.879, 0.888, 0.871, 0.862, 0.854]
test_log_accu = [0.853, 0.794, 0.735, 0.735, 0.676, 0.735, 0.676, 0.647, 0.824, 0.794, 0.794, 0.735]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.336
# p-value: 0.285
# c/d model:
# Pearson correction coeffificent: 0.466
# p-value: 0.127
# c-d model:
# Pearson correction coeffificent: 0.436
# p-value: 0.156
# c/d model:
# Pearson correction coeffificent: -0.531
# p-value: 0.075

# %% [markdown]
# ## Accumulated Layers with 75% Attention Heads Zeroed

# %%
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.5, 0.577, 0.623, 0.665, 0.632, 0.64, 0.676, 0.632, 0.631, 0.585, 0.563, 0.473]
train_diff_accu = [0.4, 0.523, 0.662, 0.677, 0.569, 0.538, 0.631, 0.585, 0.615, 0.477, 0.508, 0.354]
test_diff_auc = [0.688, 0.688, 0.738, 0.75, 0.7, 0.721, 0.704, 0.7, 0.683, 0.646, 0.592, 0.612]
test_diff_accu = [0.706, 0.588, 0.765, 0.735, 0.735, 0.706, 0.706, 0.676, 0.676, 0.676, 0.588, 0.588]
train_ratio_auc = [0.495, 0.544, 0.572, 0.621, 0.577, 0.583, 0.608, 0.586, 0.561, 0.542, 0.535, 0.524]
train_ratio_accu = [0.431, 0.615, 0.554, 0.554, 0.477, 0.508, 0.523, 0.631, 0.585, 0.569, 0.462, 0.477]
test_ratio_auc = [0.796, 0.813, 0.833, 0.867, 0.788, 0.792, 0.817, 0.817, 0.812, 0.8, 0.788, 0.775]
test_ratio_accu = [0.824, 0.853, 0.794, 0.853, 0.735, 0.706, 0.676, 0.676, 0.676, 0.735, 0.765, 0.676]
train_log_auc = [0.495, 0.544, 0.572, 0.621, 0.577, 0.583, 0.608, 0.586, 0.561, 0.542, 0.535, 0.524]
train_log_accu = [0.431, 0.615, 0.554, 0.554, 0.477, 0.508, 0.523, 0.631, 0.585, 0.569, 0.462, 0.477]
test_log_auc = [0.796, 0.813, 0.833, 0.867, 0.788, 0.792, 0.817, 0.817, 0.812, 0.8, 0.788, 0.775]
test_log_accu = [0.824, 0.853, 0.794, 0.853, 0.735, 0.706, 0.676, 0.676, 0.676, 0.735, 0.765, 0.676]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.677
# p-value: 0.016
# c/d model:
# Pearson correction coeffificent: 0.654
# p-value: 0.021
# c-d model:
# Pearson correction coeffificent: 0.593
# p-value: 0.042
# c/d model:
# Pearson correction coeffificent: -0.04
# p-value: 0.902

# %% [markdown]
# ## Accumulated Layers with 100% Attention Heads Zeroed

# %%
train_con_auc = [0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508, 0.508]
train_con_accu = [0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492, 0.492]
test_con_auc = [0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779, 0.779]
test_con_accu = [0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647, 0.647]
train_diff_auc = [0.5, 0.577, 0.623, 0.665, 0.632, 0.64, 0.676, 0.632, 0.631, 0.585, 0.563, 0.473]
train_diff_accu = [0.4, 0.523, 0.662, 0.677, 0.569, 0.538, 0.631, 0.585, 0.615, 0.477, 0.508, 0.354]
test_diff_auc = [0.688, 0.688, 0.738, 0.75, 0.7, 0.721, 0.704, 0.7, 0.683, 0.646, 0.592, 0.612]
test_diff_accu = [0.706, 0.588, 0.765, 0.735, 0.735, 0.706, 0.706, 0.676, 0.676, 0.676, 0.588, 0.588]
train_ratio_auc = [0.495, 0.544, 0.572, 0.621, 0.577, 0.583, 0.608, 0.586, 0.561, 0.542, 0.535, 0.524]
train_ratio_accu = [0.431, 0.615, 0.554, 0.554, 0.477, 0.508, 0.523, 0.631, 0.585, 0.569, 0.462, 0.477]
test_ratio_auc = [0.796, 0.813, 0.833, 0.867, 0.788, 0.792, 0.817, 0.817, 0.812, 0.8, 0.788, 0.775]
test_ratio_accu = [0.824, 0.853, 0.794, 0.853, 0.735, 0.706, 0.676, 0.676, 0.676, 0.735, 0.765, 0.676]
train_log_auc = [0.495, 0.544, 0.572, 0.621, 0.577, 0.583, 0.608, 0.586, 0.561, 0.542, 0.535, 0.524]
train_log_accu = [0.431, 0.615, 0.554, 0.554, 0.477, 0.508, 0.523, 0.631, 0.585, 0.569, 0.462, 0.477]
test_log_auc = [0.796, 0.813, 0.833, 0.867, 0.788, 0.792, 0.817, 0.817, 0.812, 0.8, 0.788, 0.775]
test_log_accu = [0.824, 0.853, 0.794, 0.853, 0.735, 0.706, 0.676, 0.676, 0.676, 0.735, 0.765, 0.676]
make_auc_plot(train_con_auc, test_con_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(train_con_accu, test_con_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.677
# p-value: 0.016
# c/d model:
# Pearson correction coeffificent: 0.654
# p-value: 0.021
# c-d model:
# Pearson correction coeffificent: 0.593
# p-value: 0.042
# c/d model:
# Pearson correction coeffificent: -0.04
# p-value: 0.902
