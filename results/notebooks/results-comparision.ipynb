# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

def make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers):
    plt.rcParams["figure.figsize"] = (20,5)
    plt.plot(layers, con_train_auc, label="control train")
    plt.plot(layers, con_test_auc, label="control test")
    plt.plot(layers, train_diff_auc, label="c-d train")
    plt.plot(layers, test_diff_auc, label="c-d test")
    plt.plot(layers, train_ratio_auc, label="c/d train")
    plt.plot(layers, test_ratio_auc, label="c/d test")
    if max(layers) == 11:
        plt.xlabel("n-th layers")
        plt.ylabel("AUC")
        plt.title("AUC on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(0, 12, 1.0))
    else:
        plt.xlabel("first n layers")
        plt.ylabel("AUC")
        plt.title("AUC on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(1, 13, 1.0))
    for x, y in zip(layers, train_diff_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_diff_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, train_ratio_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_ratio_auc):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    plt.show()
    print("c-d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_diff_auc, test_diff_auc)[0], 3),
                                                                    round(pearsonr(train_diff_auc, test_diff_auc)[1], 3)))
    print("c/d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_ratio_auc, test_ratio_auc)[0], 3),
                                                                    round(pearsonr(train_ratio_auc, test_ratio_auc)[1], 3)))

    
def make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers):
    plt.rcParams["figure.figsize"] = (20,5)
    plt.plot(layers, con_train_accu, label="control train")
    plt.plot(layers, con_test_accu, label="control test")
    plt.plot(layers, train_diff_accu, label="c-d train")
    plt.plot(layers, test_diff_accu, label="c-d test")
    plt.plot(layers, train_ratio_accu, label="c/d train")
    plt.plot(layers, test_ratio_accu, label="c/d test")
    if max(layers) == 12:
        plt.xlabel("n-th layers")
        plt.ylabel("Accuracy")
        plt.title("Accuracy on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(0, 12, 1.0))
    else:
        plt.xlabel("first n layers")
        plt.ylabel("Accuracy")
        plt.title("Accuracy on Training and Test Set")
        plt.legend()
        plt.xticks(np.arange(1, 13, 1.0))
    for x, y in zip(layers, train_diff_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_diff_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, train_ratio_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    for x, y in zip(layers, test_ratio_accu):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                     (x,y), # this is the point to label
                     textcoords="offset points", # how to position the text
                     xytext=(0,10), # distance from text to points (x,y)
                     ha='center')
    plt.show()
    print("c-d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_diff_accu, test_diff_accu)[0], 3),
                                                                    round(pearsonr(train_diff_accu, test_diff_accu)[1], 3)))
    print("c/d model:")
    print("Pearson correction coeffificent: {}\np-value: {}".format(round(pearsonr(train_ratio_accu, test_ratio_accu)[0], 3),
                                                                    round(pearsonr(train_ratio_accu, test_ratio_accu)[1], 3)))

# %%
layers = list(range(0, 12))
con_train_auc = [0.569]*12
con_train_accu = [0.528]*12
con_test_auc = [0.759, 0.759, 0.759, 0.759, 0.759, 0.759, 0.759, 0.759, 0.759, 0.759, 0.759, 0.759]
con_test_accu = [0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75]

# %% [markdown]
# ## Onetime Layer-wise with 25% Attention Heads Zeroed

# %%
train_diff_auc = [0.571, 0.532, 0.504, 0.503, 0.361, 0.507, 0.509, 0.458, 0.564, 0.587, 0.419, 0.524]
train_diff_accu = [0.537, 0.528, 0.481, 0.5, 0.38, 0.481, 0.463, 0.454, 0.537, 0.565, 0.472, 0.5]
test_diff_auc = [0.649, 0.443, 0.352, 0.634, 0.608, 0.618, 0.597, 0.424, 0.51, 0.425, 0.403, 0.398]
test_diff_accu = [0.542, 0.458, 0.375, 0.583, 0.562, 0.562, 0.625, 0.479, 0.5, 0.438, 0.396, 0.417]
train_ratio_auc = [0.609, 0.524, 0.51, 0.52, 0.359, 0.52, 0.516, 0.475, 0.623, 0.625, 0.428, 0.523]
train_ratio_accu = [0.546, 0.454, 0.472, 0.509, 0.38, 0.481, 0.463, 0.444, 0.593, 0.63, 0.417, 0.444]
test_ratio_auc = [0.731, 0.484, 0.396, 0.648, 0.606, 0.648, 0.592, 0.446, 0.656, 0.535, 0.418, 0.448]
test_ratio_accu = [0.604, 0.479, 0.417, 0.562, 0.583, 0.583, 0.583, 0.438, 0.604, 0.625, 0.458, 0.458]
train_log_auc = [0.609, 0.524, 0.51, 0.52, 0.359, 0.52, 0.516, 0.475, 0.623, 0.625, 0.428, 0.523]
train_log_accu = [0.546, 0.454, 0.472, 0.509, 0.38, 0.481, 0.463, 0.444, 0.593, 0.63, 0.417, 0.444]
test_log_auc = [0.731, 0.484, 0.396, 0.648, 0.606, 0.648, 0.592, 0.446, 0.656, 0.535, 0.418, 0.448]
test_log_accu = [0.604, 0.479, 0.417, 0.562, 0.583, 0.583, 0.583, 0.438, 0.604, 0.625, 0.458, 0.458]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: -0.029
# p-value: 0.929
# c/d model:
# Pearson correction coeffificent: 0.361
# p-value: 0.25
# c-d model:
# Pearson correction coeffificent: -0.259
# p-value: 0.417
# c/d model:
# Pearson correction coeffificent: 0.574
# p-value: 0.051

# %% [markdown]
# ## Onetime Layer-wise with 50% Attention Heads Zeroed

# %%
train_diff_auc = [0.534, 0.497, 0.544, 0.462, 0.377, 0.467, 0.555, 0.462, 0.688, 0.485, 0.406, 0.463]
train_diff_accu = [0.519, 0.454, 0.556, 0.463, 0.38, 0.463, 0.528, 0.463, 0.62, 0.481, 0.37, 0.444]
test_diff_auc = [0.644, 0.495, 0.47, 0.51, 0.472, 0.552, 0.564, 0.469, 0.481, 0.241, 0.335, 0.42]
test_diff_accu = [0.604, 0.625, 0.521, 0.562, 0.458, 0.583, 0.5, 0.417, 0.542, 0.333, 0.333, 0.458]
train_ratio_auc = [0.548, 0.494, 0.548, 0.481, 0.376, 0.51, 0.585, 0.476, 0.739, 0.513, 0.448, 0.499]
train_ratio_accu = [0.472, 0.444, 0.537, 0.5, 0.38, 0.5, 0.556, 0.481, 0.676, 0.546, 0.435, 0.509]
test_ratio_auc = [0.741, 0.512, 0.498, 0.523, 0.451, 0.618, 0.618, 0.583, 0.663, 0.302, 0.47, 0.503]
test_ratio_accu = [0.708, 0.625, 0.438, 0.562, 0.417, 0.562, 0.625, 0.604, 0.625, 0.333, 0.438, 0.458]
train_log_auc = [0.548, 0.494, 0.548, 0.481, 0.376, 0.51, 0.585, 0.476, 0.739, 0.513, 0.448, 0.499]
train_log_accu = [0.472, 0.444, 0.537, 0.5, 0.38, 0.5, 0.556, 0.481, 0.676, 0.546, 0.435, 0.509]
test_log_auc = [0.741, 0.512, 0.498, 0.523, 0.451, 0.618, 0.618, 0.583, 0.663, 0.302, 0.47, 0.503]
test_log_accu = [0.708, 0.625, 0.438, 0.562, 0.417, 0.562, 0.625, 0.604, 0.625, 0.333, 0.438, 0.458]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.288
# p-value: 0.364
# c/d model:
# Pearson correction coeffificent: 0.505
# p-value: 0.094
# c-d model:
# Pearson correction coeffificent: 0.411
# p-value: 0.184
# c/d model:
# Pearson correction coeffificent: 0.181
# p-value: 0.573

# %% [markdown]
# ## Onetime Layer-wise with 75% Attention Heads Zeroed

# %%
train_diff_auc = [0.534, 0.549, 0.558, 0.494, 0.455, 0.434, 0.468, 0.433, 0.484, 0.409, 0.43, 0.42]
train_diff_accu = [0.509, 0.537, 0.574, 0.481, 0.472, 0.463, 0.463, 0.463, 0.481, 0.389, 0.444, 0.426]
test_diff_auc = [0.637, 0.488, 0.443, 0.457, 0.538, 0.462, 0.5, 0.467, 0.351, 0.24, 0.387, 0.384]
test_diff_accu = [0.583, 0.5, 0.479, 0.521, 0.521, 0.458, 0.562, 0.458, 0.375, 0.25, 0.438, 0.417]
train_ratio_auc = [0.562, 0.546, 0.571, 0.497, 0.459, 0.469, 0.513, 0.454, 0.54, 0.393, 0.471, 0.451]
train_ratio_accu = [0.519, 0.537, 0.565, 0.454, 0.463, 0.481, 0.472, 0.444, 0.472, 0.407, 0.509, 0.463]
test_ratio_auc = [0.757, 0.486, 0.47, 0.509, 0.533, 0.609, 0.573, 0.601, 0.5, 0.292, 0.498, 0.49]
test_ratio_accu = [0.708, 0.5, 0.438, 0.458, 0.542, 0.583, 0.5, 0.562, 0.438, 0.396, 0.438, 0.438]
train_log_auc = [0.562, 0.546, 0.571, 0.497, 0.459, 0.469, 0.513, 0.454, 0.54, 0.393, 0.471, 0.451]
train_log_accu = [0.519, 0.537, 0.565, 0.454, 0.463, 0.481, 0.472, 0.444, 0.472, 0.407, 0.509, 0.463]
test_log_auc = [0.757, 0.486, 0.47, 0.509, 0.533, 0.609, 0.573, 0.601, 0.5, 0.292, 0.498, 0.49]
test_log_accu = [0.708, 0.5, 0.438, 0.458, 0.542, 0.583, 0.5, 0.562, 0.438, 0.396, 0.438, 0.438]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.518
# p-value: 0.085
# c/d model:
# Pearson correction coeffificent: 0.457
# p-value: 0.135
# c-d model:
# Pearson correction coeffificent: 0.581
# p-value: 0.048
# c/d model:
# Pearson correction coeffificent: 0.202
# p-value: 0.53

# %% [markdown]
# ## Onetime Layer-wise with 100% Attention Heads Zeroed

# %%
train_diff_auc = [0.552, 0.482, 0.429, 0.521, 0.414, 0.479, 0.51, 0.489, 0.512, 0.426, 0.377, 0.384]
train_diff_accu = [0.519, 0.463, 0.491, 0.509, 0.407, 0.463, 0.472, 0.463, 0.481, 0.417, 0.389, 0.444]
test_diff_auc = [0.448, 0.384, 0.373, 0.531, 0.53, 0.443, 0.457, 0.502, 0.359, 0.217, 0.337, 0.389]
test_diff_accu = [0.438, 0.333, 0.438, 0.583, 0.542, 0.5, 0.5, 0.417, 0.458, 0.25, 0.333, 0.417]
train_ratio_auc = [0.573, 0.473, 0.447, 0.535, 0.425, 0.522, 0.572, 0.511, 0.556, 0.433, 0.379, 0.447]
train_ratio_accu = [0.519, 0.481, 0.509, 0.565, 0.407, 0.519, 0.481, 0.463, 0.519, 0.481, 0.417, 0.491]
test_ratio_auc = [0.568, 0.405, 0.446, 0.585, 0.543, 0.569, 0.589, 0.597, 0.536, 0.321, 0.399, 0.573]
test_ratio_accu = [0.542, 0.312, 0.458, 0.583, 0.5, 0.521, 0.542, 0.583, 0.521, 0.375, 0.438, 0.625]
train_log_auc = [0.573, 0.473, 0.447, 0.535, 0.425, 0.522, 0.572, 0.511, 0.556, 0.433, 0.379, 0.447]
train_log_accu = [0.519, 0.481, 0.509, 0.565, 0.407, 0.519, 0.481, 0.463, 0.519, 0.481, 0.417, 0.491]
test_log_auc = [0.568, 0.405, 0.446, 0.585, 0.543, 0.569, 0.589, 0.597, 0.536, 0.321, 0.399, 0.573]
test_log_accu = [0.542, 0.312, 0.458, 0.583, 0.5, 0.521, 0.542, 0.583, 0.521, 0.375, 0.438, 0.625]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.405
# p-value: 0.192
# c/d model:
# Pearson correction coeffificent: 0.654
# p-value: 0.021
# c-d model:
# Pearson correction coeffificent: 0.446
# p-value: 0.146
# c/d model:
# Pearson correction coeffificent: 0.287
# p-value: 0.365

# %% [markdown]
# ## Accumulated Layers with 25% Attention Heads Zeroed

# %%
layers = list(range(1, 13))

train_diff_auc = [0.571, 0.596, 0.632, 0.678, 0.682, 0.679, 0.686, 0.691, 0.684, 0.684, 0.679, 0.672]
train_diff_accu = [0.537, 0.556, 0.593, 0.648, 0.639, 0.667, 0.667, 0.722, 0.685, 0.648, 0.667, 0.685]
test_diff_auc = [0.649, 0.62, 0.675, 0.736, 0.741, 0.731, 0.785, 0.786, 0.785, 0.748, 0.738, 0.722]
test_diff_accu = [0.542, 0.562, 0.583, 0.604, 0.646, 0.708, 0.729, 0.708, 0.792, 0.708, 0.646, 0.667]
train_ratio_auc = [0.609, 0.621, 0.655, 0.685, 0.682, 0.723, 0.741, 0.737, 0.737, 0.74, 0.739, 0.732]
train_ratio_accu = [0.546, 0.574, 0.602, 0.639, 0.611, 0.676, 0.676, 0.63, 0.63, 0.611, 0.648, 0.62]
test_ratio_auc = [0.731, 0.717, 0.793, 0.83, 0.837, 0.835, 0.875, 0.859, 0.856, 0.856, 0.837, 0.825]
test_ratio_accu = [0.604, 0.604, 0.729, 0.75, 0.688, 0.792, 0.792, 0.812, 0.729, 0.812, 0.729, 0.771]
train_log_auc = [0.609, 0.621, 0.655, 0.685, 0.682, 0.723, 0.741, 0.737, 0.737, 0.74, 0.739, 0.732]
train_log_accu = [0.546, 0.574, 0.602, 0.639, 0.611, 0.676, 0.676, 0.63, 0.63, 0.611, 0.648, 0.62]
test_log_auc = [0.731, 0.717, 0.793, 0.83, 0.837, 0.835, 0.875, 0.859, 0.856, 0.856, 0.837, 0.825]
test_log_accu = [0.604, 0.604, 0.729, 0.75, 0.688, 0.792, 0.792, 0.812, 0.729, 0.812, 0.729, 0.771]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.911
# p-value: 0.0
# c/d model:
# Pearson correction coeffificent: 0.921
# p-value: 0.0
# c-d model:
# Pearson correction coeffificent: 0.819
# p-value: 0.001
# c/d model:
# Pearson correction coeffificent: 0.766
# p-value: 0.004

# %% [markdown]
# ## Accumulated Layers with 50% Attention Heads Zeroed

# %%
layers = list(range(1, 13))
train_diff_auc = [0.534, 0.612, 0.633, 0.675, 0.692, 0.702, 0.7, 0.716, 0.721, 0.703, 0.688, 0.682]
train_diff_accu = [0.519, 0.593, 0.62, 0.602, 0.62, 0.639, 0.648, 0.676, 0.648, 0.648, 0.63, 0.63]
test_diff_auc = [0.644, 0.684, 0.696, 0.726, 0.766, 0.806, 0.797, 0.788, 0.809, 0.759, 0.727, 0.727]
test_diff_accu = [0.604, 0.667, 0.667, 0.604, 0.646, 0.708, 0.688, 0.688, 0.771, 0.667, 0.583, 0.646]
train_ratio_auc = [0.548, 0.644, 0.656, 0.698, 0.71, 0.719, 0.723, 0.731, 0.74, 0.737, 0.726, 0.723]
train_ratio_accu = [0.472, 0.537, 0.574, 0.63, 0.648, 0.648, 0.648, 0.667, 0.685, 0.648, 0.639, 0.62]
test_ratio_auc = [0.741, 0.821, 0.818, 0.872, 0.892, 0.908, 0.906, 0.906, 0.92, 0.906, 0.903, 0.894]
test_ratio_accu = [0.708, 0.708, 0.688, 0.729, 0.75, 0.75, 0.771, 0.771, 0.854, 0.854, 0.833, 0.833]
train_log_auc = [0.548, 0.644, 0.656, 0.698, 0.71, 0.719, 0.723, 0.731, 0.74, 0.737, 0.726, 0.723]
train_log_accu = [0.472, 0.537, 0.574, 0.63, 0.648, 0.648, 0.648, 0.667, 0.685, 0.648, 0.639, 0.62]
test_log_auc = [0.741, 0.821, 0.818, 0.872, 0.892, 0.908, 0.906, 0.906, 0.92, 0.906, 0.903, 0.894]
test_log_accu = [0.708, 0.708, 0.688, 0.729, 0.75, 0.75, 0.771, 0.771, 0.854, 0.854, 0.833, 0.833]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.905
# p-value: 0.0
# c/d model:
# Pearson correction coeffificent: 0.989
# p-value: 0.0
# c-d model:
# Pearson correction coeffificent: 0.542
# p-value: 0.069
# c/d model:
# Pearson correction coeffificent: 0.643
# p-value: 0.024

# %% [markdown]
# ## Accumulated Layers with 75% Attention Heads Zeroed¶

# %%
train_diff_auc = [0.534, 0.622, 0.67, 0.711, 0.711, 0.75, 0.768, 0.757, 0.732, 0.695, 0.662, 0.64]
train_diff_accu = [0.509, 0.583, 0.639, 0.639, 0.648, 0.667, 0.639, 0.657, 0.639, 0.648, 0.62, 0.574]
test_diff_auc = [0.637, 0.674, 0.715, 0.769, 0.748, 0.785, 0.773, 0.781, 0.778, 0.707, 0.663, 0.642]
test_diff_accu = [0.583, 0.688, 0.667, 0.729, 0.667, 0.771, 0.688, 0.688, 0.729, 0.625, 0.625, 0.604]
train_ratio_auc = [0.562, 0.62, 0.656, 0.693, 0.681, 0.705, 0.715, 0.699, 0.69, 0.676, 0.665, 0.658]
train_ratio_accu = [0.519, 0.593, 0.574, 0.62, 0.602, 0.667, 0.62, 0.63, 0.602, 0.611, 0.602, 0.583]
test_ratio_auc = [0.757, 0.786, 0.806, 0.84, 0.804, 0.812, 0.819, 0.828, 0.83, 0.804, 0.793, 0.771]
test_ratio_accu = [0.708, 0.771, 0.708, 0.729, 0.667, 0.708, 0.708, 0.729, 0.708, 0.729, 0.75, 0.667]
train_log_auc = [0.562, 0.62, 0.656, 0.693, 0.681, 0.705, 0.715, 0.699, 0.69, 0.676, 0.665, 0.658]
train_log_accu = [0.519, 0.593, 0.574, 0.62, 0.602, 0.667, 0.62, 0.63, 0.602, 0.611, 0.602, 0.583]
test_log_auc = [0.757, 0.786, 0.806, 0.84, 0.804, 0.812, 0.819, 0.828, 0.83, 0.804, 0.793, 0.771]
test_log_accu = [0.708, 0.771, 0.708, 0.729, 0.667, 0.708, 0.708, 0.729, 0.708, 0.729, 0.75, 0.667]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.901
# p-value: 0.0
# c/d model:
# Pearson correction coeffificent: 0.826
# p-value: 0.001
# c-d model:
# Pearson correction coeffificent: 0.673
# p-value: 0.016
# c/d model:
# Pearson correction coeffificent: 0.118
# p-value: 0.715

# %% [markdown]
# ## Accumulated Layers with 100% Attention Heads Zeroed

# %%
train_diff_auc = [0.552, 0.495, 0.532, 0.576, 0.623, 0.593, 0.633, 0.614, 0.588, 0.593, 0.577, 0.59]
train_diff_accu = [0.519, 0.472, 0.519, 0.537, 0.574, 0.519, 0.546, 0.537, 0.546, 0.537, 0.574, 0.583]
test_diff_auc = [0.448, 0.411, 0.517, 0.549, 0.597, 0.526, 0.597, 0.583, 0.512, 0.486, 0.45, 0.481]
test_diff_accu = [0.438, 0.438, 0.5, 0.542, 0.479, 0.479, 0.583, 0.521, 0.521, 0.458, 0.479, 0.5]
train_ratio_auc = [0.573, 0.525, 0.592, 0.645, 0.688, 0.675, 0.712, 0.699, 0.685, 0.675, 0.648, 0.647]
train_ratio_accu = [0.519, 0.491, 0.546, 0.63, 0.62, 0.611, 0.648, 0.667, 0.648, 0.648, 0.593, 0.63]
test_ratio_auc = [0.568, 0.531, 0.715, 0.856, 0.851, 0.764, 0.812, 0.802, 0.752, 0.733, 0.707, 0.71]
test_ratio_accu = [0.542, 0.542, 0.667, 0.688, 0.708, 0.667, 0.792, 0.688, 0.688, 0.583, 0.625, 0.625]
train_log_auc = [0.573, 0.525, 0.592, 0.645, 0.688, 0.675, 0.712, 0.699, 0.685, 0.675, 0.648, 0.647]
train_log_accu = [0.519, 0.491, 0.546, 0.63, 0.62, 0.611, 0.648, 0.667, 0.648, 0.648, 0.593, 0.63]
test_log_auc = [0.568, 0.531, 0.715, 0.856, 0.851, 0.764, 0.812, 0.802, 0.752, 0.733, 0.707, 0.71]
test_log_accu = [0.542, 0.542, 0.667, 0.688, 0.708, 0.667, 0.792, 0.688, 0.688, 0.583, 0.625, 0.625]
make_auc_plot(con_train_auc, con_test_auc, train_diff_auc, test_diff_auc, train_ratio_auc, test_ratio_auc, layers)
make_accu_plot(con_train_accu, con_test_accu, train_diff_accu, test_diff_accu, train_ratio_accu, test_ratio_accu, layers)
# Out:
# c-d model:
# Pearson correction coeffificent: 0.778
# p-value: 0.003
# c/d model:
# Pearson correction coeffificent: 0.846
# p-value: 0.001
# c-d model:
# Pearson correction coeffificent: 0.351
# p-value: 0.264
# c/d model:
# Pearson correction coeffificent: 0.657
# p-value: 0.02
