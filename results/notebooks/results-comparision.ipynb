# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# %% [markdown]
# ## Onetime Layer-wise with 25% Attention Heads Zeroed

# %%
layers = list(range(0, 12))
con_auc = [0.569]*12
con_accu = [0.528]*12

train_diff_auc = [0.571, 0.532, 0.504, 0.503, 0.361, 0.507, 0.509, 0.458, 0.564, 0.587, 0.419, 0.524]
train_diff_accu = [0.537, 0.528, 0.481, 0.5, 0.38, 0.481, 0.463, 0.454, 0.537, 0.565, 0.472, 0.5]
test_diff_auc = [0.649, 0.443, 0.352, 0.634, 0.608, 0.618, 0.597, 0.424, 0.51, 0.425, 0.403, 0.398]
test_diff_accu = [0.542, 0.458, 0.375, 0.583, 0.562, 0.562, 0.625, 0.479, 0.5, 0.438, 0.396, 0.417]
train_ratio_auc = [0.609, 0.524, 0.51, 0.52, 0.359, 0.52, 0.516, 0.475, 0.623, 0.625, 0.428, 0.523]
train_ratio_accu = [0.546, 0.454, 0.472, 0.509, 0.38, 0.481, 0.463, 0.444, 0.593, 0.63, 0.417, 0.444]
test_ratio_auc = [0.731, 0.484, 0.396, 0.648, 0.606, 0.648, 0.592, 0.446, 0.656, 0.535, 0.418, 0.448]
test_ratio_accu = [0.604, 0.479, 0.471, 0.562, 0.583, 0.583, 0.583, 0.438, 0.604, 0.625, 0.458, 0.458]
train_log_auc = [0.609, 0.524, 0.51, 0.52, 0.359, 0.52, 0.516, 0.475, 0.623, 0.625, 0.428, 0.523]
train_log_accu = [0.546, 0.454, 0.472, 0.509, 0.38, 0.481, 0.463, 0.444, 0.593, 0.63, 0.417, 0.444]
test_log_auc = [0.731, 0.484, 0.396, 0.648, 0.606, 0.648, 0.592, 0.446, 0.656, 0.535, 0.418, 0.448]
test_log_accu = [0.604, 0.479, 0.417, 0.562, 0.583, 0.583, 0.583, 0.438, 0.604, 0.625, 0.458, 0.458]

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_auc, label="control")
plt.plot(layers, train_diff_auc, label="c-d train")
plt.plot(layers, test_diff_auc, label="c-d test")
plt.plot(layers, train_ratio_auc, label="c/d train")
plt.plot(layers, test_ratio_auc, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("AUC on Training and Test Set")
plt.legend()
plt.xticks(np.arange(0, 12, 1.0))
for x, y in zip(layers, train_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_auc, test_diff_auc)[0],
                                                                pearsonr(train_diff_auc, test_diff_auc)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_auc, test_ratio_auc)[0],
                                                                pearsonr(train_ratio_auc, test_ratio_auc)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: -0.02870235075265558
# p-value: 0.9294428386841888
# c/d model:
# Pearson correction coeffificent: 0.36058107855402505
# p-value: 0.24955034709342291

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_accu, label="control")
plt.plot(layers, train_diff_accu, label="c-d train")
plt.plot(layers, test_diff_accu, label="c-d test")
plt.plot(layers, train_ratio_accu, label="c/d train")
plt.plot(layers, test_ratio_accu, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("Accuracy on Training and Test Set")
plt.legend()
plt.xticks(np.arange(0, 12, 1.0))
for x, y in zip(layers, train_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_accu, test_diff_accu)[0],
                                                                pearsonr(train_diff_accu, test_diff_accu)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_accu, test_ratio_accu)[0],
                                                                pearsonr(train_ratio_accu, test_ratio_accu)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: -0.2587817372094522
# p-value: 0.4166992717878841
# c/d model:
# Pearson correction coeffificent: 0.6109036762471555
# p-value: 0.034842420651237924

# %% [markdown]
# ## Onetime Layer-wise with 50% Attention Heads Zeroed

# %%
train_diff_auc = [0.534, 0.497, 0.544, 0.462, 0.377, 0.467, 0.555, 0.462, 0.688, 0.485, 0.406, 0.453]
train_diff_accu = [0.519, 0.454, 0.556, 0.463, 0.38, 0.463, 0.528, 0.463, 0.62, 0.481, 0.37, 0.444]
test_diff_auc = [0.644, 0.495, 0.47, 0.51, 0.472, 0.552, 0.564, 0.469, 0.481, 0.241, 0.335, 0.42]
test_diff_accu = [0.604, 0.625, 0.521, 0.562, 0.458, 0.583, 0.5, 0.417, 0.542, 0.333, 0.333, 0.458]
train_ratio_auc = [0.548, 0.494, 0.548, 0.481, 0.376, 0.51, 0.585, 0.476, 0.749, 0.513, 0.448, 0.499]
train_ratio_accu = [0.472, 0.444, 0.537, 0.5, 0.38, 0.5, 0.556, 0.481, 0.676, 0.546, 0.435, 0.509]
test_ratio_auc = [0.741, 0.512, 0.498, 0.523, 0.451, 0.618, 0.618, 0.583, 0.663, 0.302, 0.47, 0.503]
test_ratio_accu = [0.798, 0.625, 0.438, 0.562, 0.417, 0.562, 0.625, 0.604, 0.625, 0.333, 0.438, 0.458]
train_log_auc = [0.548, 0.494, 0.548, 0.481, 0.376, 0.51, 0.585, 0.476, 0.739, 0.513, 0.448, 0.499]
train_log_accu = [0.472, 0.444, 0.537, 0.5, 0.38, 0.5, 0.556, 0.481, 0.676, 0.546, 0.435, 0.509]
test_log_auc = [0.741, 0.512, 0.498, 0.523, 0.451, 0.618, 0.618, 0.583, 0.663, 0.302, 0.47, 0.503]
test_log_accu = [0.708, 0.625, 0.438, 0.562, 0.417, 0.562, 0.625, 0.604, 0.625, 0.333, 0.438, 0.458]

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_auc, label="control")
plt.plot(layers, train_diff_auc, label="c-d train")
plt.plot(layers, test_diff_auc, label="c-d test")
plt.plot(layers, train_ratio_auc, label="c/d train")
plt.plot(layers, test_ratio_auc, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("AUC on Training and Test Set")
plt.legend()
plt.xticks(np.arange(0, 12, 1.0))
for x, y in zip(layers, train_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_auc, test_diff_auc)[0],
                                                                pearsonr(train_diff_auc, test_diff_auc)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_auc, test_ratio_auc)[0],
                                                                pearsonr(train_ratio_auc, test_ratio_auc)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.29210479351365237
# p-value: 0.35690062925520116
# c/d model:
# Pearson correction coeffificent: 0.5026835653672739
# p-value: 0.09577996645378613

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_accu, label="control")
plt.plot(layers, train_diff_accu, label="c-d train")
plt.plot(layers, test_diff_accu, label="c-d test")
plt.plot(layers, train_ratio_accu, label="c/d train")
plt.plot(layers, test_ratio_accu, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("Accuracy on Training and Test Set")
plt.legend()
plt.xticks(np.arange(0, 12, 1.0))
for x, y in zip(layers, train_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_accu, test_diff_accu)[0],
                                                                pearsonr(train_diff_accu, test_diff_accu)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_accu, test_ratio_accu)[0],
                                                                pearsonr(train_ratio_accu, test_ratio_accu)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.41136496163500896
# p-value: 0.18399360060162084
# c/d model:
# Pearson correction coeffificent: 0.13329259391652226
# p-value: 0.679622700888265

# %% [markdown]
# ## Onetime Layer-wise with 100% Attention Heads Z

# %%
train_diff_auc = [0.552, 0.482, 0.429, 0.521, 0.414, 0.479, 0.51, 0.489, 0.512, 0.426, 0.528, 0.384]
train_diff_accu = [0.519, 0.463, 0.491, 0.509, 0.407, 0.463, 0.472, 0.463, 0.481, 0.417, 0.377, 0.444]
test_diff_auc = [0.448, 0.384, 0.373, 0.531, 0.53, 0.443, 0.457, 0.502, 0.359, 0.217, 0.389, 0.389]
test_diff_accu = [0.438, 0.333, 0.438, 0.583, 0.542, 0.5, 0.5, 0.417, 0.458, 0.25, 0.337, 0.417]
train_ratio_auc = [0.573, 0.473, 0.447, 0.535, 0.425, 0.522, 0.572, 0.511, 0.556, 0.433, 0.333, 0.447]
train_ratio_accu = [0.519, 0.481, 0.509, 0.565, 0.407, 0.519, 0.481, 0.463, 0.519, 0.481, 0.379, 0.491]
test_ratio_auc = [0.568, 0.405, 0.446, 0.585, 0.543, 0.569, 0.589, 0.597, 0.536, 0.321, 0.417, 0.573]
test_ratio_accu = [0.542, 0.312, 0.458, 0.583, 0.5, 0.521, 0.542, 0.583, 0.521, 0.375, 0.399, 0.625]
train_log_auc = [0.573, 0.473, 0.447, 0.535, 0.425, 0.522, 0.572, 0.511, 0.556, 0.433, 0.438, 0.447]
train_log_accu = [0.519, 0.481, 0.509, 0.565, 0.407, 0.519, 0.481, 0.463, 0.519, 0.481, 0.379, 0.491]
test_log_auc = [0.568, 0.405, 0.446, 0.585, 0.543, 0.569, 0.589, 0.597, 0.536, 0.321, 0.399, 0.573]
test_log_accu = [0.542, 0.312, 0.458, 0.593, 0.5, 0.521, 0.542, 0.583, 0.521, 0.375, 0.438, 0.625]

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_auc, label="control")
plt.plot(layers, train_diff_auc, label="c-d train")
plt.plot(layers, test_diff_auc, label="c-d test")
plt.plot(layers, train_ratio_auc, label="c/d train")
plt.plot(layers, test_ratio_auc, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("AUC on Training and Test Set")
plt.legend()
plt.xticks(np.arange(0, 12, 1.0))
for x, y in zip(layers, train_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_auc, test_diff_auc)[0],
                                                                pearsonr(train_diff_auc, test_diff_auc)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_auc, test_ratio_auc)[0],
                                                                pearsonr(train_ratio_auc, test_ratio_auc)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.2759274998320081
# p-value: 0.38533749929981514
# c/d model:
# Pearson correction coeffificent: 0.625417977609593
# p-value: 0.029634802437491795

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_accu, label="control")
plt.plot(layers, train_diff_accu, label="c-d train")
plt.plot(layers, test_diff_accu, label="c-d test")
plt.plot(layers, train_ratio_accu, label="c/d train")
plt.plot(layers, test_ratio_accu, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("Accuracy on Training and Test Set")
plt.legend()
plt.xticks(np.arange(1, 13, 1.0))
for x, y in zip(layers, train_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_accu, test_diff_accu)[0],
                                                                pearsonr(train_diff_accu, test_diff_accu)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_accu, test_ratio_accu)[0],
                                                                pearsonr(train_ratio_accu, test_ratio_accu)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.44662580783596034
# p-value: 0.1455208742688546
# c/d model:
# Pearson correction coeffificent: 0.3666532224086248
# p-value: 0.24107639908752085

# %% [markdown]
# ## Accumulated Layers with 25% Attention Heads Zeroed

# %%
layers = list(range(1, 13))
con_auc = [0.569]*12
con_accu = [0.528]*12
train_diff_auc = [0.571, 0.596, 0.632, 0.678, 0.682, 0.679, 0.686, 0.691, 0.684, 0.684, 0.679, 0.672]
train_ratio_auc = [0.609, 0.621, 0.655, 0.685, 0.682, 0.723, 0.741, 0.737, 0.737, 0.74, 0.739, 0.732]
train_log_auc = [0.609, 0.621, 0.655, 0.685, 0.682, 0.723, 0.741, 0.737, 0.737, 0.74, 0.739, 0.732]

train_diff_accu = [0.537, 0.556, 0.593, 0.648, 0.639, 0.667, 0.667, 0.722, 0.685, 0.648, 0.667, 0.685]
train_ratio_accu = [0.546, 0.574, 0.602, 0.639, 0.611, 0.676, 0.676, 0.63, 0.63, 0.611, 0.648, 0.62]
train_log_accu = [0.546, 0.574, 0.602, 0.639, 0.611, 0.676, 0.676, 0.63, 0.63, 0.611, 0.648, 0.62]

test_diff_auc = [0.649, 0.62, 0.675, 0.736, 0.741, 0.731, 0.785, 0.786, 0.785, 0.748, 0.738, 0.722]
test_ratio_auc = [0.731, 0.717, 0.793, 0.83, 0.837, 0.835, 0.875, 0.859, 0.856, 0.856, 0.837, 0.825]
test_log_auc = [0.731, 0.717, 0.793, 0.83, 0.837, 0.835, 0.875, 0.859, 0.856, 0.856, 0.837, 0.825]

test_diff_accu = [0.542, 0.562, 0.583, 0.604, 0.646, 0.708, 0.729, 0.708, 0.792, 0.708, 0.646, 0.667]
test_ratio_accu = [0.604, 0.604, 0.729, 0.75, 0.688, 0.792, 0.792, 0.812, 0.729, 0.812, 0.771, 0.771]
test_log_accu = [0.604, 0.604, 0.729, 0.75, 0.688, 0.792, 0.792, 0.812, 0.729, 0.812, 0.771, 0.771]

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_auc, label="control")
plt.plot(layers, train_diff_auc, label="c-d train")
plt.plot(layers, test_diff_auc, label="c-d test")
plt.plot(layers, train_ratio_auc, label="c/d train")
plt.plot(layers, test_ratio_auc, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("AUC on Training and Test Set")
plt.legend()
plt.xticks(np.arange(1, 13, 1.0))
for x, y in zip(layers, train_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_auc, test_diff_auc)[0],
                                                                pearsonr(train_diff_auc, test_diff_auc)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_auc, test_ratio_auc)[0],
                                                                pearsonr(train_ratio_auc, test_ratio_auc)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.9114096577296246
# p-value: 3.697899492447075e-05
# c/d model:
# Pearson correction coeffificent: 0.9209635423199117
# p-value: 2.1247259762120344e-05

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_accu, label="control")
plt.plot(layers, train_diff_accu, label="c-d train")
plt.plot(layers, test_diff_accu, label="c-d test")
plt.plot(layers, train_ratio_accu, label="c/d train")
plt.plot(layers, test_ratio_accu, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("Accuracy on Training and Test Set")
plt.legend()
plt.xticks(np.arange(1, 13, 1.0))
for x, y in zip(layers, train_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_accu, test_diff_accu)[0],
                                                                pearsonr(train_diff_accu, test_diff_accu)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_accu, test_ratio_accu)[0],
                                                                pearsonr(train_ratio_accu, test_ratio_accu)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.819067681450191
# p-value: 0.0011172970113977315
# c/d model:
# Pearson correction coeffificent: 0.7947856749545672
# p-value: 0.002007571567279168

# %% [markdown]
# ## Accumulated Layers with 50% Attention Heads Zeroed

# %%
layers = list(range(1, 13))
con_auc = [0.569]*12
con_accu = [0.528]*12
train_diff_auc = [0.534, 0.612, 0.633, 0.675, 0.692, 0.702, 0.7, 0.716, 0.721, 0.703, 0.688, 0.682]
train_diff_accu = [0.519, 0.593, 0.62, 0.602, 0.62, 0.639, 0.648, 0.676, 0.648, 0.648, 0.63, 0.63]
test_diff_auc = [0.644, 0.684, 0.696, 0.726, 0.766, 0.806, 0.797, 0.788, 0.809, 0.759, 0.727, 0.727]
test_diff_accu = [0.604, 0.667, 0.667, 0.604, 0.646, 0.708, 0.688, 0.688, 0.771, 0.667, 0.583, 0.646]
train_ratio_auc = [0.548, 0.644, 0.656, 0.698, 0.71, 0.719, 0.723, 0.731, 0.74, 0.737, 0.726, 0.723]
train_ratio_accu = [0.472, 0.537, 0.574, 0.63, 0.648, 0.648, 0.648, 0.667, 0.685, 0.648, 0.639, 0.62]
test_ratio_auc = [0.741, 0.821, 0.818, 0.872, 0.892, 0.908, 0.906, 0.906, 0.92, 0.906, 0.903, 0.894]
test_ratio_accu = [0.708, 0.708, 0.688,  0.729, 0.75, 0.75, 0.771, 0.771, 0.854, 0.854, 0.833, 0.833]
train_log_auc = [0.548, 0.644, 0.656, 0.698, 0.71, 0.719, 0.723, 0.731, 0.74, 0.737, 0.726, 0.723]
train_log_accu = [0.472, 0.537, 0.574, 0.63, 0.648, 0.648, 0.648, 0.667, 0.685, 0.648, 0.639, 0.62]
test_log_auc = [0.741, 0.821, 0.818, 0.872, 0.892, 0.908, 0.906, 0.906, 0.92, 0.906, 0.903, 0.894]
test_log_accu = [0.708, 0.708, 0.688, 0.729, 0.75, 0.75, 0.771, 0.771, 0.854, 0.854, 0.833, 0.833]

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_auc, label="control")
plt.plot(layers, train_diff_auc, label="c-d train")
plt.plot(layers, test_diff_auc, label="c-d test")
plt.plot(layers, train_ratio_auc, label="c/d train")
plt.plot(layers, test_ratio_auc, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("AUC on Training and Test Set")
plt.legend()
plt.xticks(np.arange(1, 13, 1.0))
for x, y in zip(layers, train_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_auc, test_diff_auc)[0],
                                                                pearsonr(train_diff_auc, test_diff_auc)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_auc, test_ratio_auc)[0],
                                                                pearsonr(train_ratio_auc, test_ratio_auc)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.9047724174605429
# p-value: 5.24637545228141e-05
# c/d model:
# Pearson correction coeffificent: 0.9885481505157159
# p-value: 1.5216734636137324e-09

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_accu, label="control")
plt.plot(layers, train_diff_accu, label="c-d train")
plt.plot(layers, test_diff_accu, label="c-d test")
plt.plot(layers, train_ratio_accu, label="c/d train")
plt.plot(layers, test_ratio_accu, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("Accuracy on Training and Test Set")
plt.legend()
plt.xticks(np.arange(1, 13, 1.0))
for x, y in zip(layers, train_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_accu, test_diff_accu)[0],
                                                                pearsonr(train_diff_accu, test_diff_accu)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_accu, test_ratio_accu)[0],
                                                                pearsonr(train_ratio_accu, test_ratio_accu)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.5416319054430125
# p-value: 0.06893003661618358
# c/d model:
# Pearson correction coeffificent: 0.6432070549731073
# p-value: 0.02404665698661834

# %% [markdown]
# ## Accumulated Layers with 100% Attention Heads Zeroed

# %%
train_diff_auc = [0.552, 0.495, 0.532, 0.576, 0.623, 0.593, 0.633, 0.614, 0.588, 0.593, 0.577, 0.59]
train_diff_accu = [0.519, 0.472, 0.519, 0.537, 0.574, 0.519, 0.546, 0.537, 0.546, 0.537, 0.574, 0.583]
test_diff_auc = [0.448, 0.411, 0.517, 0.549, 0.597, 0.526, 0.597, 0.583, 0.512, 0.486, 0.45, 0.481]
test_diff_accu = [0.438, 0.438, 0.5, 0.542, 0.479, 0.479, 0.583, 0.521, 0.521, 0.458, 0.479, 0.5]
train_ratio_auc = [0.573, 0.525, 0.592, 0.645, 0.688, 0.675, 0.712, 0.699, 0.685, 0.675, 0.648, 0.647]
train_ratio_accu = [0.519, 0.491, 0.546, 0.63, 0.62, 0.611, 0.648, 0.667, 0.648, 0.648, 0.593, 0.63]
test_ratio_auc = [0.568, 0.531, 0.715, 0.856, 0.851, 0.764, 0.812, 0.802, 0.752, 0.733, 0.707, 0.71]
test_ratio_accu = [0.542, 0.542, 0.667, 0.688, 0.708, 0.667, 0.792, 0.688, 0.688, 0.583, 0.625, 0.625]
train_log_auc = [0.573, 0.525, 0.592, 0.645, 0.688, 0.675, 0.712, 0.699, 0.685, 0.675, 0.648, 0.647]
train_log_accu = [0.519, 0.491, 0.546, 0.63, 0.62, 0.611, 0.648, 0.667, 0.648, 0.648, 0.593, 0.63]
test_log_auc = [0.568, 0.531, 0.715, 0.856, 0.851, 0.764, 0.812, 0.802, 0.752, 0.733, 0.707, 0.71]
test_log_accu = [0.542, 0.542, 0.667, 0.688, 0.708, 0.667, 0.792, 0.688, 0.688, 0.583, 0.625, 0.625]

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_auc, label="control")
plt.plot(layers, train_diff_auc, label="c-d train")
plt.plot(layers, test_diff_auc, label="c-d test")
plt.plot(layers, train_ratio_auc, label="c/d train")
plt.plot(layers, test_ratio_auc, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("AUC on Training and Test Set")
plt.legend()
plt.xticks(np.arange(1, 13, 1.0))
for x, y in zip(layers, train_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_auc):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_auc, test_diff_auc)[0],
                                                                pearsonr(train_diff_auc, test_diff_auc)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_auc, test_ratio_auc)[0],
                                                                pearsonr(train_ratio_auc, test_ratio_auc)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.7775061347404871
# p-value: 0.002914879995532761
# c/d model:
# Pearson correction coeffificent: 0.8459826151201992
# p-value: 0.0005238815143602902

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.plot(layers, con_accu, label="control")
plt.plot(layers, train_diff_accu, label="c-d train")
plt.plot(layers, test_diff_accu, label="c-d test")
plt.plot(layers, train_ratio_accu, label="c/d train")
plt.plot(layers, test_ratio_accu, label="c/d test")
plt.xlabel("first n layers")
plt.ylabel("AUC")
plt.title("Accuracy on Training and Test Set")
plt.legend()
plt.xticks(np.arange(1, 13, 1.0))
for x, y in zip(layers, train_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_diff_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, train_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
for x, y in zip(layers, test_ratio_accu):
    label = "{:.2f}".format(y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.show()
print("c-d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_diff_accu, test_diff_accu)[0],
                                                                pearsonr(train_diff_accu, test_diff_accu)[1]))
print("c/d model:")
print("Pearson correction coeffificent: {}\np-value: {}".format(pearsonr(train_ratio_accu, test_ratio_accu)[0],
                                                                pearsonr(train_ratio_accu, test_ratio_accu)[1]))
# Out:
# c-d model:
# Pearson correction coeffificent: 0.3507461355496673
# p-value: 0.2636409224240785
# c/d model:
# Pearson correction coeffificent: 0.6567127525243902
# p-value: 0.020347206363028416
